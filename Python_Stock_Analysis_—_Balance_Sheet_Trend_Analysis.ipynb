# %% [markdown]
# <a href="https://colab.research.google.com/github/ragalaa/Machine-Learning-Basics/blob/master/Python_Stock_Analysis_%E2%80%94_Balance_Sheet_Trend_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json
""" This was  best API for all financials info for free data to fethced
    https://financialmodelingprep.com/api
"""
bs = requests.get('https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/AAPL?period=Quarter')
bs = bs.json()
bsfinance = bs['financials']
bsfinal = pd.DataFrame.from_dict(bsfinance)
bsfinal = bsfinal.T
bsfinal.columns = bsfinal.iloc[0]

# %%
cols = bsfinal.columns
bsfinal = bsfinal.iloc[1:,]
bsfinal = bsfinal.iloc[:12,:4]
cols = bsfinal.columns
bsfinal[cols] = bsfinal[cols].apply(pd.to_numeric, errors='coerce')
bsfinal
# Out:
# date                               2019-09-28  ...    2016-09-24
# Cash and cash equivalents        4.884400e+10  ...  2.048400e+10
# Short-term investments           5.171300e+10  ...  4.667100e+10
# Cash and short-term investments  1.005570e+11  ...  6.715500e+10
# Receivables                      2.292600e+10  ...  1.575400e+10
# Inventories                      4.106000e+09  ...  2.132000e+09
# Total current assets             1.628190e+11  ...  1.068690e+11
# Property, Plant & Equipment Net  3.737800e+10  ...  2.701000e+10
# Goodwill and Intangible Assets   0.000000e+00  ...  8.620000e+09
# Long-term investments            1.053410e+11  ...  1.704300e+11
# Tax assets                       0.000000e+00  ...  0.000000e+00
# Total non-current assets         1.756970e+11  ...  2.148170e+11
# Total assets                     3.385160e+11  ...  3.216860e+11
#
# [12 rows x 4 columns]

# %%
assetsQ1 = bsfinal.iloc[11,0]
assetsQ2 = bsfinal.iloc[11,1]
assetsQ3 = bsfinal.iloc[11,2]
assetsQ4 = bsfinal.iloc[11,3]
allassets = [assetsQ1,assetsQ2,assetsQ3,assetsQ4]
bsfinal[cols] = (bsfinal[cols] / allassets)*100
pd.options.display.float_format = '{:.2f}%'.format
bsfinal
# Out:
# date                             2019-09-28  2018-09-29  2017-09-30  2016-09-24
# Cash and cash equivalents            14.43%       7.09%       5.41%       6.37%
# Short-term investments               15.28%      11.04%      14.36%      14.51%
# Cash and short-term investments      29.71%      18.13%      19.76%      20.88%
# Receivables                           6.77%       6.34%       4.76%       4.90%
# Inventories                           1.21%       1.08%       1.29%       0.66%
# Total current assets                 48.10%      35.91%      34.28%      33.22%
# Property, Plant & Equipment Net      11.04%      11.29%       9.00%       8.40%
# Goodwill and Intangible Assets        0.00%       0.00%       2.14%       2.68%
# Long-term investments                31.12%      46.70%      51.88%      52.98%
# Tax assets                            0.00%       0.00%       0.00%       0.00%
# Total non-current assets             51.90%      64.09%      65.72%      66.78%
# ...
